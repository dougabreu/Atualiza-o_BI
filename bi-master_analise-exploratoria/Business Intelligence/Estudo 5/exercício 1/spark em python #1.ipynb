# %% [markdown]
# # Tutorial - Spark en Python
# Este notebook foi desenvolvido para apresentar alguns conceitos básicos e ajudar você a se familiarizar com o uso do Spark no Python.
#
# Neste notebook, carregaremos e exploraremos o conjunto de dados mtcars. Especificamente, este tutorial abrange:
#
# 1. Carregando dados na memória
# 1. Criando SQLContext
# 1. Criando Spark DataFrame
# 1. Agrupe dados por colunas
# 1. Operando em colunas
# 1. Executando consultas SQL a partir de um Spark DataFrame

# %% [markdown]
# ## Carregando em um DataFrame
#
# Para criar um Spark DataFrame, carregamos um DataFrame externo, chamado `mtcars`. Este DataFrame inclui 32 observações em 11 variáveis.
#
# [, 1]	mpg	Miles/(US) --> gallon
# [, 2]	cyl	--> Number of cylinders
# [, 3]	disp	--> Displacement (cu.in.)
# [, 4]	hp -->	Gross horsepower
# [, 5]	drat -->	Rear axle ratio
# [, 6]	wt -->	Weight (lb/1000)
# [, 7]	qsec -->	1/4 mile time
# [, 8]	vs -->	V/S
# [, 9]	am -->	Transmission (0 = automatic, 1 = manual)
# [,10]	gear -->	Number of forward gears
# [,11]	carb -->	Number of carburetors

# %%
dbutils.fs.ls('FileStore/tables')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [FileInfo(path=&#39;dbfs:/FileStore/tables/PS_20174392719_1491204439457_log.csv&#39;, name=&#39;PS_20174392719_1491204439457_log.csv&#39;, size=493534783),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/diamonds/&#39;, name=&#39;diamonds/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/movies.csv&#39;, name=&#39;movies.csv&#39;, size=236368),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/mtcars.xls&#39;, name=&#39;mtcars.xls&#39;, size=1700),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/occupation.csv&#39;, name=&#39;occupation.csv&#39;, size=22628),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/ratings.csv&#39;, name=&#39;ratings.csv&#39;, size=1979173),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/test/&#39;, name=&#39;test/&#39;, size=0)]</div>

# %%
import pandas as pd
mtcars = pd.read_csv('/dbfs/FileStore/tables/mtcars.xls')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mtcars.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>mpg</th>
#       <th>cyl</th>
#       <th>disp</th>
#       <th>hp</th>
#       <th>drat</th>
#       <th>wt</th>
#       <th>qsec</th>
#       <th>vs</th>
#       <th>am</th>
#       <th>gear</th>
#       <th>carb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Mazda RX4</td>
#       <td>21.0</td>
#       <td>6</td>
#       <td>160.0</td>
#       <td>110</td>
#       <td>3.90</td>
#       <td>2.620</td>
#       <td>16.46</td>
#       <td>0</td>
#       <td>1</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mazda RX4 Wag</td>
#       <td>21.0</td>
#       <td>6</td>
#       <td>160.0</td>
#       <td>110</td>
#       <td>3.90</td>
#       <td>2.875</td>
#       <td>17.02</td>
#       <td>0</td>
#       <td>1</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Datsun 710</td>
#       <td>22.8</td>
#       <td>4</td>
#       <td>108.0</td>
#       <td>93</td>
#       <td>3.85</td>
#       <td>2.320</td>
#       <td>18.61</td>
#       <td>1</td>
#       <td>1</td>
#       <td>4</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Hornet 4 Drive</td>
#       <td>21.4</td>
#       <td>6</td>
#       <td>258.0</td>
#       <td>110</td>
#       <td>3.08</td>
#       <td>3.215</td>
#       <td>19.44</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Hornet Sportabout</td>
#       <td>18.7</td>
#       <td>8</td>
#       <td>360.0</td>
#       <td>175</td>
#       <td>3.15</td>
#       <td>3.440</td>
#       <td>17.02</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Inicializar SQLContext
# Para trabalhar com quadros de dados, precisamos de um SQLContext que seja criado usando `SQLContext (sc)`. SQLContext usa SparkContext que já foi criado, chamado `sqlContext`.

# %%
type(sqlContext)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: pyspark.sql.context.HiveContext</div>

# %% [markdown]
# ## Criando quadros de dados do Spark
# Com o SQLContext e um DataFrame local carregado, criamos um Spark DataFrame:

# %%
sdf = sqlContext.createDataFrame(mtcars) 
sdf.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- model: string (nullable = true)
# -- mpg: double (nullable = true)
# -- cyl: long (nullable = true)
# -- disp: double (nullable = true)
# -- hp: long (nullable = true)
# -- drat: double (nullable = true)
# -- wt: double (nullable = true)
# -- qsec: double (nullable = true)
# -- vs: long (nullable = true)
# -- am: long (nullable = true)
# -- gear: long (nullable = true)
# -- carb: long (nullable = true)
#
# </div>

# %% [markdown]
# ## Exibe o conteúdo do DataFrame

# %%
sdf.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
#             model| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
#         Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|  0|  1|   4|   4|
#     Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|  0|  1|   4|   4|
#        Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|  1|  1|   4|   1|
#    Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|  1|  0|   3|   1|
# Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|  0|  0|   3|   2|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ## Selecionando colunas

# %%
sdf.select('mpg').show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+
#  mpg|
# +----+
# 21.0|
# 21.0|
# 22.8|
# 21.4|
# 18.7|
# +----+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ## Filtrando dados
# Filtre o DataFrame para reter apenas linhas com mpg menor que 18

# %%
sdf.filter(sdf['mpg'] < 18).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+----+---+-----+---+----+----+-----+---+---+----+----+
#       model| mpg|cyl| disp| hp|drat|  wt| qsec| vs| am|gear|carb|
# +-----------+----+---+-----+---+----+----+-----+---+---+----+----+
#  Duster 360|14.3|  8|360.0|245|3.21|3.57|15.84|  0|  0|   3|   4|
#   Merc 280C|17.8|  6|167.6|123|3.92|3.44| 18.9|  1|  0|   4|   4|
#  Merc 450SE|16.4|  8|275.8|180|3.07|4.07| 17.4|  0|  0|   3|   3|
#  Merc 450SL|17.3|  8|275.8|180|3.07|3.73| 17.6|  0|  0|   3|   3|
# Merc 450SLC|15.2|  8|275.8|180|3.07|3.78| 18.0|  0|  0|   3|   3|
# +-----------+----+---+-----+---+----+----+-----+---+---+----+----+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ## Operando em colunas
# O Spark também fornece várias funções que podem ser aplicadas diretamente às colunas para processamento e agregação de dados. O exemplo abaixo mostra o uso de funções aritméticas básicas para converter lb em tonelada métrica.

# %%
sdf.withColumn('wtTon', sdf['wt'] * 0.45).show(6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+-------+
#             model| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|  wtTon|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+-------+
#         Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|  0|  1|   4|   4|  1.179|
#     Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|  0|  1|   4|   4|1.29375|
#        Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|  1|  1|   4|   1|  1.044|
#    Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|  1|  0|   3|   1|1.44675|
# Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|  0|  0|   3|   2|  1.548|
#           Valiant|18.1|  6|225.0|105|2.76| 3.46|20.22|  1|  0|   3|   1|  1.557|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+-------+
# only showing top 6 rows
#
# </div>

# %%
sdf.show(6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
#             model| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
#         Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|  0|  1|   4|   4|
#     Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|  0|  1|   4|   4|
#        Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|  1|  1|   4|   1|
#    Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|  1|  0|   3|   1|
# Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|  0|  0|   3|   2|
#           Valiant|18.1|  6|225.0|105|2.76| 3.46|20.22|  1|  0|   3|   1|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# only showing top 6 rows
#
# </div>

# %% [markdown]
# ## Agrupamento, Agregação
# Os DataFrames do Spark oferecem suporte a várias funções comumente usadas para agregar dados após o agrupamento. Por exemplo, podemos calcular o peso médio dos carros por seus cilindros, como mostrado abaixo:

# %%
sdf.groupby(['cyl'])\
.agg({"wt": "avg"})\
.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------------------+
# cyl|           avg(wt)|
# +---+------------------+
#   6| 3.117142857142857|
#   8|3.9992142857142854|
#   4| 2.285727272727273|
# +---+------------------+
#
# </div>

# %%
# Também podemos classificar a saída da agregação para obter os carros mais comuns
car_counts = sdf.groupby(['cyl'])\
.agg({"wt": "count"})\
.sort("count(wt)", ascending=False)\
.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---------+
# cyl|count(wt)|
# +---+---------+
#   8|       14|
#   4|       11|
#   6|        7|
# +---+---------+
#
# </div>

# %% [markdown]
# ### Executando consultas SQL a partir de Spark DataFrames
# Um Spark DataFrame também pode ser registrado como uma tabela temporária no Spark SQL e o registro de um DataFrame como uma tabela permite executar consultas SQL sobre seus dados. A função `sql` permite que os aplicativos executem consultas SQL programaticamente e retorna o resultado como um DataFrame.

# %%
# Register this DataFrame as a table.
sdf.registerTempTable("cars")

# SQL statements can be run by using the sql method
highgearcars = sqlContext.sql("SELECT gear FROM cars WHERE cyl >= 4 AND cyl <= 9")
highgearcars.show(6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+
# gear|
# +----+
#    4|
#    4|
#    4|
#    3|
#    3|
#    3|
# +----+
# only showing top 6 rows
#
# </div>
